# %% [markdown]
# # Q4: k-center clustering

# %% [markdown]
# ## Downloading the dataset
#
# In the following code cell, we download the dataset, which I have uploaded on a public GitHub repository.
#
# Dataset used: [Credit Card Dataset for Clustering](https://www.kaggle.com/arjunbhasin2013/ccdata)

# %%
import requests 

url = "https://raw.githubusercontent.com/frank-chris/CS-328-Assignments/main/HW-1/CC%20GENERAL.csv"

r = requests.get(url) 

with open("CC GENERAL.csv",'wb') as f: 
    f.write(r.content)

# %% [markdown]
# ## Reading the csv file into a DataFrame and processing before use

# %% [markdown]
# In the following cell, we read the csv file into a DataFrame and set the CUST_ID column as the index.

# %%
import pandas as pd
import numpy as np
import random
from itertools import combinations

dataset = pd.read_csv('CC GENERAL.csv')
dataset.set_index('CUST_ID', inplace=True)
dataset.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT       TENURE
# count   8950.000000        8950.000000  ...       8950.000000  8950.000000
# mean    1564.474828           0.877271  ...          0.153715    11.517318
# std     2081.531879           0.236904  ...          0.292499     1.338331
# min        0.000000           0.000000  ...          0.000000     6.000000
# 25%      128.281915           0.888889  ...          0.000000    12.000000
# 50%      873.385231           1.000000  ...          0.000000    12.000000
# 75%     2054.140036           1.000000  ...          0.142857    12.000000
# max    19043.138560           1.000000  ...          1.000000    12.000000
#
# [8 rows x 17 columns]

# %% [markdown]
# In the nest cell, we find the number of rows having NaNs.

# %%
dataset.shape[0] - dataset.dropna().shape[0]
# Out:
# 314

# %% [markdown]
# In the next cell, we find the columns that have NaNs

# %%
dataset.columns[dataset.isna().any()].tolist()
# Out:
# ['CREDIT_LIMIT', 'MINIMUM_PAYMENTS']

# %% [markdown]
# In the next cell, we find the total number of NaN cells in the dataset.

# %%
sum(dataset.isnull().values.ravel())
# Out:
# 314

# %% [markdown]
# In the next cell, we fill the NaN cells with the mean of the corresponding column. Using the mean will not cause any deviations in the data and is better than filling with zeroes. Another option is to remove these points at the cost of loss of information.

# %%
dataset.fillna(dataset.mean(), inplace=True)

# %% [markdown]
# In the next cell, we perform min-max scaling normalisation to make sure values in all columns are in the range between 0 and 1.

# %%
dataset = (dataset-dataset.min())/(dataset.max()-dataset.min())
dataset.describe()
# Out:
#            BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT       TENURE
# count  8950.000000        8950.000000  ...       8950.000000  8950.000000
# mean      0.082154           0.877271  ...          0.153715     0.919553
# std       0.109306           0.236904  ...          0.292499     0.223055
# min       0.000000           0.000000  ...          0.000000     0.000000
# 25%       0.006736           0.888889  ...          0.000000     1.000000
# 50%       0.045864           1.000000  ...          0.000000     1.000000
# 75%       0.107868           1.000000  ...          0.142857     1.000000
# max       1.000000           1.000000  ...          1.000000     1.000000
#
# [8 rows x 17 columns]

# %% [markdown]
# ## Implementing algorithms

# %% [markdown]
# dist(a, b) gives the L2 norm of a-b, and is the distance function used.

# %%
def dist(a, b):
  return np.linalg.norm(a-b)

# %% [markdown]
# find_cost(dataset, C) returns the total cost of clustering when C is the list of centers

# %%
def find_cost(dataset, C):
  clusters = [[] for i in range(len(C))]
  for index, row in dataset.iterrows():
    dist_to_closest_center = dist(C[0], row)
    closest_center = 0
    for i, c in enumerate(C):
      if dist(c, row) <= dist_to_closest_center:
        dist_to_closest_center = dist(c, row)
        closest_center = i
    clusters[closest_center].append(dist_to_closest_center)

  cluster_costs = [max(point_costs) for point_costs in clusters]
  cost = max(cluster_costs)
  return cost

# %% [markdown]
# min_dist_from_centers(x, C) returns the minimum among the distances of the point x from the centers.

# %%
def min_dist_from_centers(x, C):
  min_dist = dist(x, C[0])
  for c in C:
    if dist(x, c) < min_dist:
      min_dist = dist(x, c)
  return min_dist

# %% [markdown]
# next_center(dataset, C) returns the next center to be chosen when C is the list centers chosen so far.

# %%
def next_center(dataset, C):
  next = dataset.iloc[0]
  for index, row in dataset.iterrows():
    if min_dist_from_centers(row, C) > min_dist_from_centers(next, C):
      next = row
  return next

# %% [markdown]
# k_center_approx(dataset, k) performs approximate k-center clustering of dataset and returns the list of centers (C) and the total cost of clustering (cost) as a tuple.

# %%
def k_center_approx(dataset, k):
  C = []
  C.append(dataset.iloc[random.randint(0, dataset.index.size - 1)])
  for i in range(k-1):
    C.append(next_center(dataset, C))

  cost = find_cost(dataset, C)
  return C, cost

# %% [markdown]
# k_center_exact(dataset, k) performs exact(optimal) k-center clustering of dataset and returns the list of centers (C_optimal) and the total cost (cost_optimal) of clustering as a tuple.

# %%
def k_center_exact(dataset, k):
  C_optimal = []
  cost_optimal = np.inf
  for index in list(combinations(dataset.index,k)):
    C = []
    for i, row in dataset.loc[index,:].iterrows():
      C.append(row)
    if find_cost(dataset, C) < cost_optimal:
      C_optimal = C
      cost_optimal = find_cost(dataset, C)
  return C_optimal, cost_optimal

# %% [markdown]
# Reporting the k-center objective value for k = 2, 4, 10 using approximate algorithm(greedy).

# %%
k_list = [2, 4, 10]

for k in k_list:
  C, cost = k_center_approx(dataset, k)
  
  print('Cost(objective value) for k =', k, 'is', cost)
# Out:
# Cost(objective value) for k = 2 is 2.051034307060489
# Cost(objective value) for k = 4 is 1.7659087627465788
# Cost(objective value) for k = 10 is 1.4892928394430194

# %% [markdown]
# Printing the centers for the clustering performed above.

# %%
for k in k_list:
  print('Centers for k =', k, ':\n')
  for i, c in enumerate(C):
    print('c -', i+1, ':\n')
    print(c, '\n')
# Out:
# Centers for k = 2 :
#
# c - 1 :
#
# BALANCE                             0.004727
# BALANCE_FREQUENCY                   0.909091
# PURCHASES                           0.025436
# ONEOFF_PURCHASES                    0.010476
# INSTALLMENTS_PURCHASES              0.036461
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.909091
# ONEOFF_PURCHASES_FREQUENCY          0.272727
# PURCHASES_INSTALLMENTS_FREQUENCY    0.818182
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.069832
# CREDIT_LIMIT                        0.165275
# PAYMENTS                            0.015040
# MINIMUM_PAYMENTS                    0.001505
# PRC_FULL_PAYMENT                    0.454545
# TENURE                              0.833333
# Name: C15304, dtype: float64
#
# c - 2 :
#
# BALANCE                             0.606387
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           1.000000
# ONEOFF_PURCHASES                    1.000000
# INSTALLMENTS_PURCHASES              0.367925
# CASH_ADVANCE                        0.011841
# PURCHASES_FREQUENCY                 1.000000
# ONEOFF_PURCHASES_FREQUENCY          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.916667
# CASH_ADVANCE_FREQUENCY              0.055555
# CASH_ADVANCE_TRX                    0.008130
# PURCHASES_TRX                       0.282123
# CREDIT_LIMIT                        0.749583
# PAYMENTS                            0.925261
# MINIMUM_PAYMENTS                    0.038924
# PRC_FULL_PAYMENT                    0.250000
# TENURE                              1.000000
# Name: C10574, dtype: float64
#
# c - 3 :
#
# BALANCE                             0.572650
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.008808
# ONEOFF_PURCHASES                    0.003275
# INSTALLMENTS_PURCHASES              0.013264
# CASH_ADVANCE                        1.000000
# PURCHASES_FREQUENCY                 0.583333
# ONEOFF_PURCHASES_FREQUENCY          0.250000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.500000
# CASH_ADVANCE_FREQUENCY              0.666667
# CASH_ADVANCE_TRX                    1.000000
# PURCHASES_TRX                       0.058659
# CREDIT_LIMIT                        0.652755
# PAYMENTS                            0.769863
# MINIMUM_PAYMENTS                    0.070598
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              1.000000
# Name: C12226, dtype: float64
#
# c - 4 :
#
# BALANCE                             0.202001
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.040996
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              1.000000
# CASH_ADVANCE_TRX                    0.146341
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.185309
# PAYMENTS                            0.009784
# MINIMUM_PAYMENTS                    0.007046
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              0.000000
# Name: C13127, dtype: float64
#
# c - 5 :
#
# BALANCE                             0.066628
# BALANCE_FREQUENCY                   0.272727
# PURCHASES                           0.365929
# ONEOFF_PURCHASES                    0.440247
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.166667
# ONEOFF_PURCHASES_FREQUENCY          0.166667
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.008380
# CREDIT_LIMIT                        0.599332
# PAYMENTS                            1.000000
# MINIMUM_PAYMENTS                    0.015048
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              1.000000
# Name: C14338, dtype: float64
#
# c - 6 :
#
# BALANCE                             0.473914
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.058350
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.055555
# CASH_ADVANCE_TRX                    0.016260
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.298831
# PAYMENTS                            0.005964
# MINIMUM_PAYMENTS                    0.798778
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              1.000000
# Name: C17325, dtype: float64
#
# c - 7 :
#
# BALANCE                             0.365296
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.234524
# ONEOFF_PURCHASES                    0.075832
# INSTALLMENTS_PURCHASES              0.373775
# CASH_ADVANCE                        0.321053
# PURCHASES_FREQUENCY                 1.000000
# ONEOFF_PURCHASES_FREQUENCY          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    1.000000
# CASH_ADVANCE_FREQUENCY              0.666667
# CASH_ADVANCE_TRX                    0.390244
# PURCHASES_TRX                       0.860335
# CREDIT_LIMIT                        0.465776
# PAYMENTS                            0.396716
# MINIMUM_PAYMENTS                    0.021163
# PRC_FULL_PAYMENT                    0.166667
# TENURE                              1.000000
# Name: C14640, dtype: float64
#
# c - 8 :
#
# BALANCE                             0.002703
# BALANCE_FREQUENCY                   0.181818
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.009967
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.055555
# CASH_ADVANCE_TRX                    0.008130
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.031720
# PAYMENTS                            0.055242
# MINIMUM_PAYMENTS                    0.001445
# PRC_FULL_PAYMENT                    1.000000
# TENURE                              1.000000
# Name: C17083, dtype: float64
#
# c - 9 :
#
# BALANCE                             0.795853
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.014626
# ONEOFF_PURCHASES                    0.017596
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.100097
# PURCHASES_FREQUENCY                 1.000000
# ONEOFF_PURCHASES_FREQUENCY          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.333333
# CASH_ADVANCE_TRX                    0.056911
# PURCHASES_TRX                       0.067039
# CREDIT_LIMIT                        0.599332
# PAYMENTS                            0.078905
# MINIMUM_PAYMENTS                    0.050309
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              1.000000
# Name: C14836, dtype: float64
#
# c - 10 :
#
# BALANCE                             0.008521
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.018515
# ONEOFF_PURCHASES                    0.022276
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.007202
# PURCHASES_FREQUENCY                 1.000000
# ONEOFF_PURCHASES_FREQUENCY          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.111111
# CASH_ADVANCE_TRX                    0.016260
# PURCHASES_TRX                       0.022346
# CREDIT_LIMIT                        0.035726
# PAYMENTS                            0.024124
# MINIMUM_PAYMENTS                    0.000986
# PRC_FULL_PAYMENT                    1.000000
# TENURE                              0.000000
# Name: C17430, dtype: float64
#
# Centers for k = 4 :
#
# c - 1 :
#
# BALANCE                             0.004727
# BALANCE_FREQUENCY                   0.909091
# PURCHASES                           0.025436
# ONEOFF_PURCHASES                    0.010476
# INSTALLMENTS_PURCHASES              0.036461
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.909091
# ONEOFF_PURCHASES_FREQUENCY          0.272727
# PURCHASES_INSTALLMENTS_FREQUENCY    0.818182
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.069832
# CREDIT_LIMIT                        0.165275
# PAYMENTS                            0.015040
# MINIMUM_PAYMENTS                    0.001505
# PRC_FULL_PAYMENT                    0.454545
# TENURE                              0.833333
# Name: C15304, dtype: float64
#
# c - 2 :
#
# BALANCE                             0.606387
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           1.000000
# ONEOFF_PURCHASES                    1.000000
# INSTALLMENTS_PURCHASES              0.367925
# CASH_ADVANCE                        0.011841
# PURCHASES_FREQUENCY                 1.000000
# ONEOFF_PURCHASES_FREQUENCY          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.916667
# CASH_ADVANCE_FREQUENCY              0.055555
# CASH_ADVANCE_TRX                    0.008130
# PURCHASES_TRX                       0.282123
# CREDIT_LIMIT                        0.749583
# PAYMENTS                            0.925261
# MINIMUM_PAYMENTS                    0.038924
# PRC_FULL_PAYMENT                    0.250000
# TENURE                              1.000000
# Name: C10574, dtype: float64
#
# c - 3 :
#
# BALANCE                             0.572650
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.008808
# ONEOFF_PURCHASES                    0.003275
# INSTALLMENTS_PURCHASES              0.013264
# CASH_ADVANCE                        1.000000
# PURCHASES_FREQUENCY                 0.583333
# ONEOFF_PURCHASES_FREQUENCY          0.250000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.500000
# CASH_ADVANCE_FREQUENCY              0.666667
# CASH_ADVANCE_TRX                    1.000000
# PURCHASES_TRX                       0.058659
# CREDIT_LIMIT                        0.652755
# PAYMENTS                            0.769863
# MINIMUM_PAYMENTS                    0.070598
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              1.000000
# Name: C12226, dtype: float64
#
# c - 4 :
#
# BALANCE                             0.202001
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.040996
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              1.000000
# CASH_ADVANCE_TRX                    0.146341
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.185309
# PAYMENTS                            0.009784
# MINIMUM_PAYMENTS                    0.007046
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              0.000000
# Name: C13127, dtype: float64
#
# c - 5 :
#
# BALANCE                             0.066628
# BALANCE_FREQUENCY                   0.272727
# PURCHASES                           0.365929
# ONEOFF_PURCHASES                    0.440247
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.166667
# ONEOFF_PURCHASES_FREQUENCY          0.166667
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.008380
# CREDIT_LIMIT                        0.599332
# PAYMENTS                            1.000000
# MINIMUM_PAYMENTS                    0.015048
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              1.000000
# Name: C14338, dtype: float64
#
# c - 6 :
#
# BALANCE                             0.473914
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.058350
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.055555
# CASH_ADVANCE_TRX                    0.016260
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.298831
# PAYMENTS                            0.005964
# MINIMUM_PAYMENTS                    0.798778
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              1.000000
# Name: C17325, dtype: float64
#
# c - 7 :
#
# BALANCE                             0.365296
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.234524
# ONEOFF_PURCHASES                    0.075832
# INSTALLMENTS_PURCHASES              0.373775
# CASH_ADVANCE                        0.321053
# PURCHASES_FREQUENCY                 1.000000
# ONEOFF_PURCHASES_FREQUENCY          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    1.000000
# CASH_ADVANCE_FREQUENCY              0.666667
# CASH_ADVANCE_TRX                    0.390244
# PURCHASES_TRX                       0.860335
# CREDIT_LIMIT                        0.465776
# PAYMENTS                            0.396716
# MINIMUM_PAYMENTS                    0.021163
# PRC_FULL_PAYMENT                    0.166667
# TENURE                              1.000000
# Name: C14640, dtype: float64
#
# c - 8 :
#
# BALANCE                             0.002703
# BALANCE_FREQUENCY                   0.181818
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.009967
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.055555
# CASH_ADVANCE_TRX                    0.008130
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.031720
# PAYMENTS                            0.055242
# MINIMUM_PAYMENTS                    0.001445
# PRC_FULL_PAYMENT                    1.000000
# TENURE                              1.000000
# Name: C17083, dtype: float64
#
# c - 9 :
#
# BALANCE                             0.795853
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.014626
# ONEOFF_PURCHASES                    0.017596
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.100097
# PURCHASES_FREQUENCY                 1.000000
# ONEOFF_PURCHASES_FREQUENCY          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.333333
# CASH_ADVANCE_TRX                    0.056911
# PURCHASES_TRX                       0.067039
# CREDIT_LIMIT                        0.599332
# PAYMENTS                            0.078905
# MINIMUM_PAYMENTS                    0.050309
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              1.000000
# Name: C14836, dtype: float64
#
# c - 10 :
#
# BALANCE                             0.008521
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.018515
# ONEOFF_PURCHASES                    0.022276
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.007202
# PURCHASES_FREQUENCY                 1.000000
# ONEOFF_PURCHASES_FREQUENCY          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.111111
# CASH_ADVANCE_TRX                    0.016260
# PURCHASES_TRX                       0.022346
# CREDIT_LIMIT                        0.035726
# PAYMENTS                            0.024124
# MINIMUM_PAYMENTS                    0.000986
# PRC_FULL_PAYMENT                    1.000000
# TENURE                              0.000000
# Name: C17430, dtype: float64
#
# Centers for k = 10 :
#
# c - 1 :
#
# BALANCE                             0.004727
# BALANCE_FREQUENCY                   0.909091
# PURCHASES                           0.025436
# ONEOFF_PURCHASES                    0.010476
# INSTALLMENTS_PURCHASES              0.036461
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.909091
# ONEOFF_PURCHASES_FREQUENCY          0.272727
# PURCHASES_INSTALLMENTS_FREQUENCY    0.818182
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.069832
# CREDIT_LIMIT                        0.165275
# PAYMENTS                            0.015040
# MINIMUM_PAYMENTS                    0.001505
# PRC_FULL_PAYMENT                    0.454545
# TENURE                              0.833333
# Name: C15304, dtype: float64
#
# c - 2 :
#
# BALANCE                             0.606387
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           1.000000
# ONEOFF_PURCHASES                    1.000000
# INSTALLMENTS_PURCHASES              0.367925
# CASH_ADVANCE                        0.011841
# PURCHASES_FREQUENCY                 1.000000
# ONEOFF_PURCHASES_FREQUENCY          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.916667
# CASH_ADVANCE_FREQUENCY              0.055555
# CASH_ADVANCE_TRX                    0.008130
# PURCHASES_TRX                       0.282123
# CREDIT_LIMIT                        0.749583
# PAYMENTS                            0.925261
# MINIMUM_PAYMENTS                    0.038924
# PRC_FULL_PAYMENT                    0.250000
# TENURE                              1.000000
# Name: C10574, dtype: float64
#
# c - 3 :
#
# BALANCE                             0.572650
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.008808
# ONEOFF_PURCHASES                    0.003275
# INSTALLMENTS_PURCHASES              0.013264
# CASH_ADVANCE                        1.000000
# PURCHASES_FREQUENCY                 0.583333
# ONEOFF_PURCHASES_FREQUENCY          0.250000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.500000
# CASH_ADVANCE_FREQUENCY              0.666667
# CASH_ADVANCE_TRX                    1.000000
# PURCHASES_TRX                       0.058659
# CREDIT_LIMIT                        0.652755
# PAYMENTS                            0.769863
# MINIMUM_PAYMENTS                    0.070598
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              1.000000
# Name: C12226, dtype: float64
#
# c - 4 :
#
# BALANCE                             0.202001
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.040996
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              1.000000
# CASH_ADVANCE_TRX                    0.146341
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.185309
# PAYMENTS                            0.009784
# MINIMUM_PAYMENTS                    0.007046
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              0.000000
# Name: C13127, dtype: float64
#
# c - 5 :
#
# BALANCE                             0.066628
# BALANCE_FREQUENCY                   0.272727
# PURCHASES                           0.365929
# ONEOFF_PURCHASES                    0.440247
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.000000
# PURCHASES_FREQUENCY                 0.166667
# ONEOFF_PURCHASES_FREQUENCY          0.166667
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.000000
# CASH_ADVANCE_TRX                    0.000000
# PURCHASES_TRX                       0.008380
# CREDIT_LIMIT                        0.599332
# PAYMENTS                            1.000000
# MINIMUM_PAYMENTS                    0.015048
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              1.000000
# Name: C14338, dtype: float64
#
# c - 6 :
#
# BALANCE                             0.473914
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.058350
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.055555
# CASH_ADVANCE_TRX                    0.016260
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.298831
# PAYMENTS                            0.005964
# MINIMUM_PAYMENTS                    0.798778
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              1.000000
# Name: C17325, dtype: float64
#
# c - 7 :
#
# BALANCE                             0.365296
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.234524
# ONEOFF_PURCHASES                    0.075832
# INSTALLMENTS_PURCHASES              0.373775
# CASH_ADVANCE                        0.321053
# PURCHASES_FREQUENCY                 1.000000
# ONEOFF_PURCHASES_FREQUENCY          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    1.000000
# CASH_ADVANCE_FREQUENCY              0.666667
# CASH_ADVANCE_TRX                    0.390244
# PURCHASES_TRX                       0.860335
# CREDIT_LIMIT                        0.465776
# PAYMENTS                            0.396716
# MINIMUM_PAYMENTS                    0.021163
# PRC_FULL_PAYMENT                    0.166667
# TENURE                              1.000000
# Name: C14640, dtype: float64
#
# c - 8 :
#
# BALANCE                             0.002703
# BALANCE_FREQUENCY                   0.181818
# PURCHASES                           0.000000
# ONEOFF_PURCHASES                    0.000000
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.009967
# PURCHASES_FREQUENCY                 0.000000
# ONEOFF_PURCHASES_FREQUENCY          0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.055555
# CASH_ADVANCE_TRX                    0.008130
# PURCHASES_TRX                       0.000000
# CREDIT_LIMIT                        0.031720
# PAYMENTS                            0.055242
# MINIMUM_PAYMENTS                    0.001445
# PRC_FULL_PAYMENT                    1.000000
# TENURE                              1.000000
# Name: C17083, dtype: float64
#
# c - 9 :
#
# BALANCE                             0.795853
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.014626
# ONEOFF_PURCHASES                    0.017596
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.100097
# PURCHASES_FREQUENCY                 1.000000
# ONEOFF_PURCHASES_FREQUENCY          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.333333
# CASH_ADVANCE_TRX                    0.056911
# PURCHASES_TRX                       0.067039
# CREDIT_LIMIT                        0.599332
# PAYMENTS                            0.078905
# MINIMUM_PAYMENTS                    0.050309
# PRC_FULL_PAYMENT                    0.000000
# TENURE                              1.000000
# Name: C14836, dtype: float64
#
# c - 10 :
#
# BALANCE                             0.008521
# BALANCE_FREQUENCY                   1.000000
# PURCHASES                           0.018515
# ONEOFF_PURCHASES                    0.022276
# INSTALLMENTS_PURCHASES              0.000000
# CASH_ADVANCE                        0.007202
# PURCHASES_FREQUENCY                 1.000000
# ONEOFF_PURCHASES_FREQUENCY          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY    0.000000
# CASH_ADVANCE_FREQUENCY              0.111111
# CASH_ADVANCE_TRX                    0.016260
# PURCHASES_TRX                       0.022346
# CREDIT_LIMIT                        0.035726
# PAYMENTS                            0.024124
# MINIMUM_PAYMENTS                    0.000986
# PRC_FULL_PAYMENT                    1.000000
# TENURE                              0.000000
# Name: C17430, dtype: float64

# %% [markdown]
# Finding the optimal cost and reporting the approximation factor obtained by the greedy algorithm for k = 2, 4 by only taking 20 (this number can be changed in the following cell) points randomly and uniformly from the dataset.

# %%
k_list = [2, 4]

subset = dataset.sample(n=20)

for k in k_list:
  C_approx, cost_approx = k_center_approx(subset, k)
  C_optimal, cost_optimal = k_center_exact(subset, k)

  print('Cost(approximate) for k =', k, 'is', cost_approx)
  print('Cost(optimal) for k =', k, 'is', cost_optimal)
  print('Approximation factor for k =', k, 'is', cost_approx/cost_optimal, '\n')
# Out:
# Cost(approximate) for k = 2 is 1.5333044038552515
# Cost(optimal) for k = 2 is 1.13214981728322
# Approximation factor for k = 2 is 1.354329948605802
#
# Cost(approximate) for k = 4 is 1.0069456800092873
# Cost(optimal) for k = 4 is 0.9791892330772924
# Approximation factor for k = 4 is 1.0283463563470412
